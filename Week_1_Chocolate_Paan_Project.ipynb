# %% [markdown]
# # AI-Based Chocolate Paan Sales Prediction System Using Machine Learning
# ## Week 1: Problem Definition & Dataset Exploration

# %%
import numpy as np
import pandas as pd
print("NumPy:",np.__version__)
print("Pandas:",pd.__version__)
# Out:
# NumPy: 2.3.5
# Pandas: 2.3.3

# %%
df=pd.read_excel("Chocolate_Paan_Sales_Dataset_10000.xlsx")
df.head()
# Out:
#          Date Day_of_Week  Month  Weekend  Festival  Season  Temperature  \
# 0  2024-01-01      Monday      1        0         0  Winter         28.3
# 1  2024-01-02     Tuesday      1        0         0  Winter         24.0
# 2  2024-01-03   Wednesday      1        0         0  Winter         24.9
# 3  2024-01-04    Thursday      1        0         1  Winter         24.0
# 4  2024-01-05      Friday      1        0         0  Winter         20.5
#
#    Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# 0      10.0    120                    0               1              0
# 1      16.9    100                   10               0              1
# 2      17.8    110                   10               1              0
# 3      13.8    140                   15               1              0
# 4       2.8    110                   10               1              1
#
#    Facebook_Ads  Marketing_Budget  Returning_Customers  New_Customers  \
# ...

# %% [markdown]
# ## Q1. Shape of dataset

# %%
df.shape
# Out:
# (10000, 20)

# %% [markdown]
# ## Q2. Column names

# %%
df.columns
# Out:
# Index(['Date', 'Day_of_Week', 'Month', 'Weekend', 'Festival', 'Season',
#        'Temperature', 'Rainfall', 'Price', 'Discount_Percentage',
#        'Instagram_Reel', 'YouTube_Video', 'Facebook_Ads', 'Marketing_Budget',
#        'Returning_Customers', 'New_Customers', 'Online_Orders',
#        'Offline_Orders', 'Customer_Rating', 'Boxes_Sold'],
#       dtype='object')

# %% [markdown]
# ## Q3. Data types

# %%
df.dtypes
# Out:
# Date                    object
# Day_of_Week             object
# Month                    int64
# Weekend                  int64
# Festival                 int64
# Season                  object
# Temperature            float64
# Rainfall               float64
# Price                    int64
# Discount_Percentage      int64
# Instagram_Reel           int64
# YouTube_Video            int64
# Facebook_Ads             int64
# Marketing_Budget         int64
# Returning_Customers      int64
# New_Customers            int64
# Online_Orders            int64
# Offline_Orders           int64
# Customer_Rating        float64
# Boxes_Sold               int64
# dtype: object

# %% [markdown]
# ## Q4. Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10000 non-null  object
#  1   Day_of_Week          10000 non-null  object
#  2   Month                10000 non-null  int64
#  3   Weekend              10000 non-null  int64
#  4   Festival             10000 non-null  int64
#  5   Season               10000 non-null  object
#  6   Temperature          10000 non-null  float64
#  7   Rainfall             10000 non-null  float64
#  8   Price                10000 non-null  int64
#  9   Discount_Percentage  10000 non-null  int64
#  10  Instagram_Reel       10000 non-null  int64
#  11  YouTube_Video        10000 non-null  int64
#  12  Facebook_Ads         10000 non-null  int64
#  13  Marketing_Budget     10000 non-null  int64
#  14  Returning_Customers  10000 non-null  int64
# ...

# %% [markdown]
# ## Q5. Statistical summary

# %%
df.describe()
# Out:
#               Month       Weekend      Festival   Temperature      Rainfall  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       6.460600      0.284900      0.073300     28.809750     35.089050
# std        3.452135      0.451389      0.260641      5.642198     50.808562
# min        1.000000      0.000000      0.000000     18.000000      0.000000
# 25%        3.000000      0.000000      0.000000     24.700000      6.900000
# 50%        6.000000      0.000000      0.000000     28.700000     13.400000
# 75%        9.000000      1.000000      0.000000     32.700000     20.000000
# max       12.000000      1.000000      1.000000     40.000000    200.000000
#
#               Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# count  10000.000000         10000.000000    10000.000000   10000.000000
# mean     119.990000            10.045000        0.494800       0.504100
# ...

# %% [markdown]
# ## Q6. First 10 rows

# %%
df.head(10)
# Out:
#          Date Day_of_Week  Month  Weekend  Festival  Season  Temperature  \
# 0  2024-01-01      Monday      1        0         0  Winter         28.3
# 1  2024-01-02     Tuesday      1        0         0  Winter         24.0
# 2  2024-01-03   Wednesday      1        0         0  Winter         24.9
# 3  2024-01-04    Thursday      1        0         1  Winter         24.0
# 4  2024-01-05      Friday      1        0         0  Winter         20.5
# 5  2024-01-06    Saturday      1        1         0  Winter         24.9
# 6  2024-01-07      Sunday      1        1         0  Winter         23.0
# 7  2024-01-08      Monday      1        0         0  Winter         27.7
# 8  2024-01-09     Tuesday      1        0         0  Winter         22.8
# 9  2024-01-10   Wednesday      1        0         0  Winter         19.4
#
#    Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# 0      10.0    120                    0               1              0
# ...

# %% [markdown]
# ## Q7. Last 10 rows

# %%
df.tail(10)
# Out:
#             Date Day_of_Week  Month  Weekend  Festival  Season  Temperature  \
# 9990  2025-05-15    Thursday      5        0         0  Summer         32.6
# 9991  2025-05-16      Friday      5        0         0  Summer         30.9
# 9992  2025-05-17    Saturday      5        1         0  Summer         30.1
# 9993  2025-05-18      Sunday      5        1         0  Summer         38.5
# 9994  2025-05-19      Monday      5        0         0  Summer         32.9
# 9995  2025-05-20     Tuesday      5        0         0  Summer         31.7
# 9996  2025-05-21   Wednesday      5        0         0  Summer         31.4
# 9997  2025-05-22    Thursday      5        0         0  Summer         39.3
# 9998  2025-05-23      Friday      5        0         0  Summer         39.1
# 9999  2025-05-24    Saturday      5        1         0  Summer         39.8
#
#       Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# ...

# %% [markdown]
# ## Q8. Missing values

# %%
df.isnull().sum()
# Out:
# Date                   0
# Day_of_Week            0
# Month                  0
# Weekend                0
# Festival               0
# Season                 0
# Temperature            0
# Rainfall               0
# Price                  0
# Discount_Percentage    0
# Instagram_Reel         0
# YouTube_Video          0
# Facebook_Ads           0
# Marketing_Budget       0
# Returning_Customers    0
# New_Customers          0
# Online_Orders          0
# Offline_Orders         0
# Customer_Rating        0
# Boxes_Sold             0
# dtype: int64

# %% [markdown]
# ## Q9. Unique Seasons

# %%
df['Season'].unique()
# Out:
# array(['Winter', 'Summer', 'Monsoon'], dtype=object)

# %% [markdown]
# ## Q10. Season counts

# %%
df['Season'].value_counts()
# Out:
# Season
# Winter     4137
# Summer     3379
# Monsoon    2484
# Name: count, dtype: int64

# %% [markdown]
# ## Q11. Average Boxes Sold

# %%
df['Boxes_Sold'].mean()
# Out:
# np.float64(165.0499)

# %% [markdown]
# ## Q12. Max Marketing Budget

# %%
df['Marketing_Budget'].max()
# Out:
# 4999

# %% [markdown]
# ## Q13. Min Marketing Budget

# %%
df['Marketing_Budget'].min()
# Out:
# 500

# %% [markdown]
# ## Q14. Festival records

# %%
df[df['Festival']==1].head()
# Out:
#           Date Day_of_Week  Month  Weekend  Festival  Season  Temperature  \
# 3   2024-01-04    Thursday      1        0         1  Winter         24.0
# 23  2024-01-24   Wednesday      1        0         1  Winter         29.2
# 26  2024-01-27    Saturday      1        1         1  Winter         26.7
# 63  2024-03-04      Monday      3        0         1  Summer         34.0
# 64  2024-03-05     Tuesday      3        0         1  Summer         37.6
#
#     Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# 3       13.8    140                   15               1              0
# 23      14.5    130                   15               0              0
# 26       2.2    110                   10               0              1
# 63       6.9    100                    0               1              0
# 64      18.5    120                   20               0              0
#
#     Facebook_Ads  Marketing_Budget  Returning_Customers  New_Customers  \
# ...

# %% [markdown]
# ## Q15. Weekend & Discount >10

# %%
df[(df['Weekend']==1)&(df['Discount_Percentage']>10)].head()
# Out:
#           Date Day_of_Week  Month  Weekend  Festival  Season  Temperature  \
# 6   2024-01-07      Sunday      1        1         0  Winter         23.0
# 19  2024-01-20    Saturday      1        1         0  Winter         26.6
# 27  2024-01-28      Sunday      1        1         0  Winter         21.4
# 47  2024-02-17    Saturday      2        1         0  Winter         22.0
# 48  2024-02-18      Sunday      2        1         0  Winter         22.6
#
#     Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# 6        3.3    140                   20               0              0
# 19       5.6    120                   15               1              0
# 27      16.8    100                   15               0              0
# 47       4.6    140                   20               1              0
# 48      16.9    100                   15               1              0
#
#     Facebook_Ads  Marketing_Budget  Returning_Customers  New_Customers  \
# ...

# %% [markdown]
# ## Q16. Average Boxes Sold by Season

# %%
df.groupby('Season')['Boxes_Sold'].mean()
# Out:
# Season
# Monsoon    163.853462
# Summer     163.787807
# Winter     166.799130
# Name: Boxes_Sold, dtype: float64

# %% [markdown]
# ## Q17. Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                         Month   Weekend  Festival  Temperature  Rainfall  \
# Month                1.000000  0.005760  0.079960    -0.277559  0.216724
# Weekend              0.005760  1.000000 -0.011758     0.017998 -0.003588
# Festival             0.079960 -0.011758  1.000000    -0.106536 -0.045585
# Temperature         -0.277559  0.017998 -0.106536     1.000000 -0.023339
# Rainfall             0.216724 -0.003588 -0.045585    -0.023339  1.000000
# Price                0.011388 -0.011467  0.011601    -0.022873 -0.006942
# Discount_Percentage  0.003255  0.002883  0.001197     0.018881  0.004598
# Instagram_Reel      -0.004580 -0.003849  0.004076    -0.003632 -0.010172
# YouTube_Video        0.015187 -0.013817 -0.006527    -0.017730  0.004245
# Facebook_Ads         0.011809  0.018943  0.001268    -0.003723  0.000578
# Marketing_Budget    -0.011191 -0.019028 -0.006378     0.008928 -0.000424
# Returning_Customers -0.006406 -0.000700 -0.011646     0.021681  0.011005
# ...

# %% [markdown]
# ## Q18. Sort by Boxes Sold

# %%
df.sort_values(by='Boxes_Sold',ascending=False).head(10)
# Out:
#             Date Day_of_Week  Month  Weekend  Festival   Season  Temperature  \
# 6849  2024-10-06      Sunday     10        1         1   Winter         18.7
# 2218  2024-01-29      Monday      1        0         1   Winter         21.8
# 1072  2024-12-08      Sunday     12        1         1   Winter         22.1
# 3570  2025-10-12      Sunday     10        1         1   Winter         27.9
# 4292  2025-10-04    Saturday     10        1         1   Winter         22.0
# 366   2025-01-01   Wednesday      1        0         1   Winter         22.7
# 8519  2025-05-04      Sunday      5        1         0   Summer         30.5
# 7613  2024-11-09    Saturday     11        1         1   Winter         23.5
# 9043  2024-10-10    Thursday     10        0         1   Winter         18.0
# 9726  2024-08-24    Saturday      8        1         1  Monsoon         26.2
#
#       Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# ...

# %% [markdown]
# ## Q19. Random Sample

# %%
df.sample(10)
# Out:
#             Date Day_of_Week  Month  Weekend  Festival   Season  Temperature  \
# 1180  2025-03-26   Wednesday      3        0         0   Summer         33.1
# 8638  2025-08-31      Sunday      8        1         1  Monsoon         28.7
# 6855  2024-10-12    Saturday     10        1         0   Winter         24.3
# 8842  2024-03-23    Saturday      3        1         0   Summer         32.0
# 6658  2024-03-29      Friday      3        0         0   Summer         35.2
# 2389  2024-07-18    Thursday      7        0         0  Monsoon         26.2
# 9036  2024-10-03    Thursday     10        0         1   Winter         23.6
# 4986  2025-08-29      Friday      8        0         1  Monsoon         30.2
# 4345  2025-11-26   Wednesday     11        0         0   Winter         28.9
# 4909  2025-06-13      Friday      6        0         0   Summer         32.0
#
#       Rainfall  Price  Discount_Percentage  Instagram_Reel  YouTube_Video  \
# ...

# %% [markdown]
# ## Q20. NumPy Array

# %%
sales=[120,150,175,200,180]
arr=np.array(sales)
print(arr)
print(arr.shape)
# Out:
# [120 150 175 200 180]
# (5,)
